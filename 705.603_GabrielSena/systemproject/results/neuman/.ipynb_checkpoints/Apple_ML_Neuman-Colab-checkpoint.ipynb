# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
! ls gdrive/MyDrive/Research
# Out:
# condacolab_install.log	Miniconda3-4.5.4-Linux-x86_64.sh  nerf
# data			ml-neuman			  nerf_pl

# %%
# %cd gdrive/MyDrive/Research/
# Out:
# /content/gdrive/MyDrive/Research

# %%
! git clone https://github.com/apple/ml-neuman.git
# Out:
# fatal: destination path 'ml-neuman' already exists and is not an empty directory.

# %%
# %cd /content/gdrive/MyDrive/Research/ml-neuman/
# Out:
# /content/gdrive/MyDrive/Research/ml-neuman

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:21
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# %cd /content/gdrive/MyDrive/Research/ml-neuman/
# Out:
# /content/gdrive/MyDrive/Research/ml-neuman

# %%
# !conda env update -n base -f environment.yml
# Out:
# done
# / WARNING conda.core.solve:_add_specs(649): pinned spec cudatoolkit=11.2 conflicts with explicit specs.  Overriding pinned spec.
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 22.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# portalocker-2.6.0    | 28 KB     | : 100% 1.0/1 [00:00<00:00,  5.70it/s]
# nettle-3.6           | 6.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.38s/it]
# freetype-2.12.1      | 884 KB    | : 100% 1.0/1 [00:00<00:00,  3.86it/s]
# blas-2.16            | 11 KB     | : 100% 1.0/1 [00:00<00:00, 12.62it/s]
# liblapack-3.8.0      | 11 KB     | : 100% 1.0/1 [00:00<00:00, 19.37it/s]
# cudatoolkit-10.2.89  | 318.0 MB  | : 100% 1.0/1 [00:08<00:00,  9.00s/it]
# libgfortran4-7.5.0   | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  3.64it/s]
# libuv-1.44.2         | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.88it/s]
# ...

# %%
# !bash setup_data_and_models.sh
# Out:
# ...
# --2022-11-30 20:08:02--  https://docs-assets.developer.apple.com/ml-research/datasets/neuman/dataset.zip
# Resolving docs-assets.developer.apple.com (docs-assets.developer.apple.com)... 17.253.25.205, 17.253.25.206, 2620:149:a14:f000::5, ...
# Connecting to docs-assets.developer.apple.com (docs-assets.developer.apple.com)|17.253.25.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2154631653 (2.0G) [application/zip]
# Saving to: ‘data/dataset.zip’
#
# dataset.zip         100%[===================>]   2.01G  50.1MB/s    in 46s
#
# 2022-11-30 20:08:48 (44.8 MB/s) - ‘data/dataset.zip’ saved [2154631653/2154631653]
#
# Downloding models
# --2022-11-30 20:08:49--  https://docs-assets.developer.apple.com/ml-research/datasets/neuman/pretrained.zip
# Resolving docs-assets.developer.apple.com (docs-assets.developer.apple.com)... 17.253.25.202, 17.253.25.204, 2620:149:a14:f000::5, ...
# ...

# %%
# %cd /content/gdrive/MyDrive/Research/ml-neuman/
# ! ls .
# Out:
# /content/gdrive/MyDrive/Research/ml-neuman

# %%
# !python render_360.py --scene_dir ./data/bike --weights_path ./out/bike_human/checkpoint.pth.tar --mode canonical_360
# Out:
# Streaming output truncated to the last 5000 lines.
# 622592 / 899415
# 624640 / 899415
# 626688 / 899415
# 628736 / 899415
# 630784 / 899415
# 632832 / 899415
# 634880 / 899415
# 636928 / 899415
# 638976 / 899415
# 641024 / 899415
# 643072 / 899415
# 645120 / 899415
# 647168 / 899415
# 649216 / 899415
# 651264 / 899415
# 653312 / 899415
# 655360 / 899415
# 657408 / 899415
# 659456 / 899415
# 661504 / 899415
# 663552 / 899415
# 665600 / 899415
# 667648 / 899415
# 669696 / 899415
# 671744 / 899415
# 673792 / 899415
# 675840 / 899415
# 677888 / 899415
# 679936 / 899415
# 681984 / 899415
# 684032 / 899415
# 686080 / 899415
# 688128 / 899415
# 690176 / 899415
# 692224 / 899415
# 694272 / 899415
# 696320 / 899415
# 698368 / 899415
# 700416 / 899415
# 702464 / 899415
# 704512 / 899415
# 706560 / 899415
# 708608 / 899415
# 710656 / 899415
# 712704 / 899415
# 714752 / 899415
# 716800 / 899415
# 718848 / 899415
# 720896 / 899415
# 722944 / 899415
# 724992 / 899415
# 727040 / 899415
# ...
